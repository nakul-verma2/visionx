# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/MyDrive/Hackathon_Dataset.zip" -d /content/

# %%
cd HackByte_Dataset
# Out:
# [Errno 2] No such file or directory: 'HackByte_Dataset'
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO


class_names = ['FireExtinguisher', 'ToolBox', 'OxygenTank']


data_yaml = f"""
train: /content/HackByte_Dataset/data/train/images
val: /content/HackByte_Dataset/data/val/images
nc: {len(class_names)}
names: {class_names}
"""


with open('/content/HackByte_Dataset/data.yaml', 'w') as f:
    f.write(data_yaml)

print("✅ data.yaml created!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ data.yaml created!

# %%
from ultralytics import YOLO


model = YOLO("/content/HackByte_Dataset/best.pt")  


model.train(
    data="/content/HackByte_Dataset/data.yaml",      
    epochs=50,             
    imgsz=640,             
    batch=16,              
    device=0,              
    pretrained=True,       
    resume=False,          
    augment=True,          
    hsv_h=0.015,           
    hsv_s=0.7,             
    hsv_v=0.4,             
    degrees=10.0,          
    translate=0.1,         
    scale=0.5,             
    shear=2.0,             
    flipud=0.5,            
    fliplr=0.5,            
    mosaic=1.0,            
    mixup=0.2              
)
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")  


model.train(
    data="/content/HackByte_Dataset/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0,
    pretrained=True,
    resume=False,
    optimizer="SGD",
    cos_lr=True,
    workers=4,
    lr0=0.005,
    lrf=0.01,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=3.0,
    warmup_momentum=0.8,
    warmup_bias_lr=0.1,
    box=0.05,
    cls=0.5,
    dfl=1.5,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=10.0,
    translate=0.1,
    scale=0.5,
    shear=2.0,
    flipud=0.5,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.2
)


metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/runs/detect/train2/weights/best.pt')  


metrics = model.val(
    data='/content/HackByte_Dataset/yolo_params.yaml',  
    imgsz=640,               
    batch=16,                   
    device=0                    
)

print(f"mAP50: {metrics.box.map50:.3f}")
print(f"mAP50-95: {metrics.box.map:.3f}")
print(f"Precision: {metrics.box.p.mean():.3f}")
print(f"Recall: {metrics.box.r.mean():.3f}")
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2349.3±722.6 MB/s, size: 2384.0 KB)
# val: Scanning /content/HackByte_Dataset/data/val/labels.cache... 154 images, 0 backgrounds, 0 corrupt: 100%|██████████| 154/154 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
#                    all        154        206       0.97      0.919      0.948      0.826
#       FireExtinguisher         67         67      0.985       0.94      0.967      0.848
#                ToolBox         60         60      0.965      0.911      0.935      0.866
#             OxygenTank         79         79       0.96      0.907      0.944      0.764
# Speed: 1.8ms preprocess, 3.0ms inference, 0.0ms loss, 2.3ms postprocess per image
# ...
